# %%
# Import necessary libraries
import os
import sys
from IPython.display import HTML, display

# Enable automatic module reloading (great for development)
# %load_ext autoreload
# %autoreload 2

# Add the directory with your visualization module to the path
sys.path.append("/Users/liam/quests/lsoc-psych/datasets")

# Import the visualization functions
from dm_math_pertoken_html import load_dm_math_data, create_dm_math_pertoken_html

# %%
# Define model sizes to analyze
model_sizes = ['14m', '31m', '70m', '160m', '410m', '1b', '1.4b', '2.8b', '6.9b']

# Base directory for your data
base_dir  = f"/Users/liam/quests/lsoc-psych/datasets/experiments/EXP000/trajectories"  # Change this to your actual path

# Load both zero-shot and few-shot data for the specified models
data_results = load_dm_math_data(
    model_sizes=model_sizes,
    base_dir=base_dir,
    max_contexts=None  # Limit to 3 contexts for testing
)
# Out:
# Loading token data...
# Loading data for 14m...
# Loading loss data from /Users/liam/quests/lsoc-psych/datasets/experiments/EXP000/trajectories/csv/14m_dm_mathematics_zero_shot.csv
# Loading all contexts
# Loading loss data from /Users/liam/quests/lsoc-psych/datasets/experiments/EXP000/trajectories/csv/14m_dm_mathematics_few_shot.csv
# Loading all contexts
# Loading data for 31m...
# Loading loss data from /Users/liam/quests/lsoc-psych/datasets/experiments/EXP000/trajectories/csv/31m_dm_mathematics_zero_shot.csv
# Loading all contexts
# Loading loss data from /Users/liam/quests/lsoc-psych/datasets/experiments/EXP000/trajectories/csv/31m_dm_mathematics_few_shot.csv
# Loading all contexts
# Loading data for 70m...
# Loading loss data from /Users/liam/quests/lsoc-psych/datasets/experiments/EXP000/trajectories/csv/70m_dm_mathematics_zero_shot.csv
# Loading all contexts
# ...

# %%
from dm_math_pertoken_html import create_dm_math_pertoken_html
# Create the visualization HTML
dataset_name = "dm_mathematics"
viz_html = create_dm_math_pertoken_html(
    all_models_results=data_results,
    selected_steps=None,  # Use all available steps
    model_name="Pythia",
    dataset_name=dataset_name
)

# Display the visualization in the notebook
viz = HTML(viz_html)
# display(viz)

# Save the HTML to a file
plotting_path = "/Users/liam/quests/lsoc-psych/datasets/plotting/pertoken_loss_htmls/all_model_sizes"
filename = f"{plotting_path}/{dataset_name}_pertoken_vis_all_models.html"
with open(filename, "w") as f:
    f.write(viz.data)

# print(f"Visualization saved to {filename}")

# %%
data_results['14m']['zero_shot']['0']
# Out:
# {'tokens': ['Solve',
#   ' 0',
#   ' =',
#   ' -',
#   '4',
#   '*',
#   'q',
#   ' -',
#   ' 21',
#   ' +',
#   ' 5',
#   ' for',
#   ' q',
#   '.',
#   '\n',
#   '-',
#   '4'],
#  'category': 'algebra - linear_1d',
#  'preview': 'Solve 0 =...',
#  'checkpoints': {'0': {'losses': [-0.0,
#     11.21,
#     10.2,
#     10.32,
#     10.9,
#     9.555,
#     10.58,
#     10.57,
#     10.336,
#     10.88,
#     10.945,
#     10.85,
#     10.266,
#     11.31,
#     11.6,
#     11.195,
#     12.15]},
#   '1': {'losses': [-0.0,
#     11.21,
#     10.2,
#     10.32,
#     10.9,
#     9.555,
#     10.58,
#     10.57,
#     10.336,
#     10.88,
#     10.945,
#     10.85,
#     10.266,
#     11.31,
#     11.6,
#     11.195,
#     12.15]},
#   '2': {'losses': [-0.0,
#     11.21,
#     10.2,
#     10.32,
#     10.9,
#     9.555,
#     10.58,
#     10.57,
#     10.336,
#     10.88,
#     10.945,
#     10.85,
#     10.266,
#     11.31,
#     11.6,
#     11.195,
#     12.15]},
# ...

# %%
model_name = 'pythia'
dataset_name = 'dm_mathematics'
max_contexts = 20
steps = None
results = load_dm_math_data(model_name, dataset_name, base_dir, max_contexts, selected_steps=steps)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       3 max_contexts = 20
#       4 steps = None
# ----> 5 results = load_dm_math_data(model_name, dataset_name, base_dir, max_contexts, selected_steps=steps)
#
# TypeError: load_dm_math_data() got multiple values for argument 'selected_steps'

# %%
import pickle
pkl = "/Users/liam/quests/lsoc-psych/datasets/experiments/EXP000/trajectories/tokens/dm_mathematics_tokens.pkl"
# read pkl
with open(pkl, "rb") as f:
    tokens = pickle.load(f)

tokens
# Out:
# {0: {'tokens': ['Solve',
#    ' 0',
#    ' =',
#    ' -',
#    '4',
#    '*',
#    'q',
#    ' -',
#    ' 21',
#    ' +',
#    ' 5',
#    ' for',
#    ' q',
#    '.',
#    '\n',
#    '-',
#    '4'],
#   'category': 'algebra - linear_1d'},
#  1: {'tokens': ['Solve',
#    ' -',
#    '25',
#    ' =',
#    ' -',
#    '7',
#    '*',
#    'c',
#    ' +',
#    ' 10',
#    ' for',
#    ' c',
#    '.',
#    '\n',
#    '5'],
#   'category': 'algebra - linear_1d'},
#  2: {'tokens': ['Solve',
#    ' -',
#    '29',
#    ' =',
#    ' 8',
#    '*',
#    'a',
#    ' +',
#    ' 3',
#    ' for',
#    ' a',
#    '.',
#    '\n',
#    '-',
#    '4'],
#   'category': 'algebra - linear_1d'},
#  3: {'tokens': ['Solve',
#    ' 14',
#    ' -',
#    ' 38',
#    ' =',
#    ' 6',
#    '*',
#    'z',
#    ' for',
#    ' z',
#    '.',
#    '\n',
#    '-',
#    '4'],
#   'category': 'algebra - linear_1d'},
#  4: {'tokens': ['Solve',
#    ' -',
#    '7',
#    '*',
#    'v',
#    ' =',
#    ' -',
#    '29',
# ...

# %%
step_pkl = "/Users/liam/quests/lsoc-psych/datasets/experiments/EXP000/trajectories/pkl/1.4b/step000000.pkl"
# read pkl
with open(step_pkl, "rb") as f:
    step = pickle.load(f)
step['dm_mathematics']
# Out:
# [{'context_idx': 0,
#   'tokens': ['Solve',
#    ' 0',
#    ' =',
#    ' -',
#    '4',
#    '*',
#    'q',
#    ' -',
#    ' 21',
#    ' +',
#    ' 5',
#    ' for',
#    ' q',
#    '.',
#    '\n',
#    '-',
#    '4'],
#   'category': 'algebra - linear_1d',
#   'loss': {'zero-shot': array([-0.   , 12.266, 12.13 , 11.07 , 10.266, 10.89 , 10.836, 10.52 ,
#           10.   , 10.63 , 10.59 , 11.06 , 11.016, 10.85 , 11.87 , 10.4  ,
#           11.39 ], dtype=float16),
#    'few-shot': array([-0.   , 12.26 , 12.13 , 11.07 , 10.266, 10.89 , 10.836, 10.52 ,
#           10.   , 10.625, 10.59 , 11.06 , 11.016, 10.85 , 11.87 , 10.4  ,
#           11.39 ], dtype=float16)}},
#  {'context_idx': 1,
#   'tokens': ['Solve',
#    ' -',
#    '25',
#    ' =',
#    ' -',
#    '7',
#    '*',
#    'c',
#    ' +',
#    ' 10',
#    ' for',
#    ' c',
#    '.',
#    '\n',
#    '5'],
#   'category': 'algebra - linear_1d',
# ...

# %%
# Define paths
from parse_experiments import create_dm_mathematics_tokens
exp_name = "EXP000"
comp_path = "/Users/liam/quests/lsoc-psych/"
base_dir = comp_path + f"datasets/experiments/{exp_name}/trajectories"
tokens_dir = os.path.join(base_dir, "tokens")
step_file = os.path.join(base_dir, "pkl/1.4b/step000000.pkl")
output_path = os.path.join(tokens_dir, "dm_mathematics_tokens.pkl")

# Create the tokens file
create_dm_mathematics_tokens(step_file, output_path)
# Out:
# Saved tokens for dm_mathematics to /Users/liam/quests/lsoc-psych/datasets/experiments/EXP000/trajectories/tokens/dm_mathematics_tokens.pkl
