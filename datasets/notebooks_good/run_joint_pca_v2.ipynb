# %%
# Import necessary libraries
import os
import sys

# Enable automatic module reloading (great for development)
# %load_ext autoreload
# %autoreload 2

# Add the directory with your visualization module to the path
sys.path.append("/Users/liam/quests/lsoc-psych/datasets")

# Import the visualization functions
from joint_pca import load_trajectory_data, TrajectoryPCA, load_token_mapping

# %%
from joint_pca import load_trajectory_data
experiment_name = "EXP000"
dataset_name = "github"
num_contexts = 50
# model_sizes = ['6.9b', '160m', '31m', '2.8b', '1.4b', '70m', '410m', '1b']
model_sizes = None
trajectory_data = load_trajectory_data(experiment_name, dataset_name, 
                                       model_sizes=model_sizes, 
                                       num_contexts=num_contexts)
tokens_dict = load_token_mapping(experiment_name, dataset_name)
# Out:
# ['14m', '6.9b', '160m', '1.4b', '2.8b', '410m', '70m', '31m', '1b']
# Loading columns for 50 contexts
# Selected context indices: [2, 15, 28, 41, 54]... (total: 50)
# Loading trajectory data: 100%|██████████| 9/9 [01:06<00:00,  7.34s/it]

# %%
from joint_pca import TrajectoryPCA

step_range = [None, None]
n_components=10
n_sparse_components=0
scale=False
run_at_init=True
pca_handler = TrajectoryPCA(trajectory_data,
                            step_range = step_range,
                            n_components=n_components,
                            n_sparse_components=n_sparse_components,
                            scale=scale,
                            run_at_init=run_at_init,
                            sparse_pca_params=None,
                            dataset_name=dataset_name,
                            num_contexts=num_contexts,)
# Out:
# Found 25600 common columns across all 9 model sizes
# Concatenated matrix shape: (1386, 25600)
# Regular PCA: Top 10 components explain 95.37% of variance
# Individual explained variance: [0.7710864  0.11300656 0.02802772 0.0168818  0.00718533 0.00634188
#  0.00415607 0.003117   0.00200962 0.0018531 ]

# %%
from joint_pca import print_enhanced_pc_loadings

print_enhanced_pc_loadings(pca_handler)
# Out:
# ====================================================================================================
# REGULAR PCA COMPONENTS (Top 10 Features per Component)
# ====================================================================================================
#
# EXPLAINED VARIANCE SUMMARY:
# Component Explained Variance (%) Cumulative Variance (%)
#       PC1                 77.11%                  77.11%
#       PC2                 11.30%                  88.41%
#       PC3                  2.80%                  91.21%
#       PC4                  1.69%                  92.90%
#       PC5                  0.72%                  93.62%
#       PC6                  0.63%                  94.25%
#       PC7                  0.42%                  94.67%
#       PC8                  0.31%                  94.98%
#       PC9                  0.20%                  95.18%
#      PC10                  0.19%                  95.37%
#
# ====================================================================================================
#
#
# PRINCIPAL COMPONENT 1 (77.11% variance)
# ----------------------------------------------------------------------------------------------------
#             Feature  Loading
#  context_171_pos_97   0.0092
# context_314_pos_500   0.0091
# context_457_pos_300   0.0088
# context_535_pos_403   0.0088
# context_509_pos_344   0.0088
# context_275_pos_393   0.0088
#   context_67_pos_35   0.0087
# context_405_pos_370   0.0087
# context_509_pos_497   0.0087
#  context_509_pos_95   0.0087
#
#
#
# PRINCIPAL COMPONENT 2 (11.30% variance)
# ----------------------------------------------------------------------------------------------------
#             Feature  Loading
# context_574_pos_408  -0.0390
# context_197_pos_427  -0.0381
#  context_574_pos_65  -0.0374
#  context_574_pos_30  -0.0366
#  context_28_pos_437  -0.0355
#  context_561_pos_87  -0.0346
# context_509_pos_104  -0.0346
# context_509_pos_394  -0.0343
# context_457_pos_196  -0.0340
# context_314_pos_500  -0.0338
#
#
#
# PRINCIPAL COMPONENT 3 (2.80% variance)
# ----------------------------------------------------------------------------------------------------
#             Feature  Loading
# context_132_pos_300   0.0198
# context_600_pos_123   0.0193
# context_379_pos_311   0.0189
# context_119_pos_145   0.0187
# context_197_pos_427   0.0187
# context_119_pos_395   0.0184
# context_496_pos_274   0.0182
#  context_262_pos_64   0.0179
# context_522_pos_157   0.0176
#  context_561_pos_87   0.0175
#
#
#
# PRINCIPAL COMPONENT 4 (1.69% variance)
# ----------------------------------------------------------------------------------------------------
#             Feature  Loading
# context_132_pos_300  -0.0532
# context_119_pos_395  -0.0528
# context_132_pos_147  -0.0516
# context_262_pos_108  -0.0500
# context_132_pos_144  -0.0488
# context_223_pos_476  -0.0438
# context_600_pos_129  -0.0434
#  context_54_pos_257  -0.0426
# context_639_pos_255  -0.0416
#   context_54_pos_52  -0.0411
#
#
#
# PRINCIPAL COMPONENT 5 (0.72% variance)
# ----------------------------------------------------------------------------------------------------
#             Feature  Loading
#  context_561_pos_41   0.0639
# context_132_pos_300   0.0565
# context_119_pos_395   0.0516
# context_418_pos_112   0.0492
# context_262_pos_108   0.0488
# context_444_pos_407   0.0486
#  context_236_pos_44  -0.0474
# context_132_pos_297   0.0472
# context_288_pos_487   0.0471
# context_418_pos_511   0.0465
#
#
#
# PRINCIPAL COMPONENT 6 (0.63% variance)
# ----------------------------------------------------------------------------------------------------
#             Feature  Loading
#  context_67_pos_410   0.0226
# context_184_pos_170   0.0213
#  context_457_pos_29   0.0211
#  context_392_pos_51   0.0206
# context_236_pos_233   0.0206
#  context_522_pos_38   0.0204
# context_314_pos_335   0.0200
# context_522_pos_339   0.0199
#  context_392_pos_22   0.0198
#  context_15_pos_501   0.0198
#
#
#
# PRINCIPAL COMPONENT 7 (0.42% variance)
# ----------------------------------------------------------------------------------------------------
#             Feature  Loading
#  context_626_pos_28   0.0909
#  context_171_pos_97   0.0546
#   context_28_pos_78  -0.0534
#  context_509_pos_88   0.0522
#  context_93_pos_386   0.0512
#  context_93_pos_275   0.0504
# context_470_pos_328   0.0490
#  context_93_pos_387   0.0485
#  context_54_pos_312   0.0483
#  context_197_pos_89   0.0469
#
#
#
# PRINCIPAL COMPONENT 8 (0.31% variance)
# ----------------------------------------------------------------------------------------------------
#             Feature  Loading
#    context_2_pos_22  -0.0645
# context_223_pos_476  -0.0616
# context_418_pos_201   0.0608
# context_418_pos_499   0.0589
# context_600_pos_459  -0.0566
#  context_67_pos_509  -0.0548
# context_522_pos_135   0.0531
# context_197_pos_157   0.0524
# context_223_pos_257  -0.0518
#  context_626_pos_28  -0.0511
#
#
#
# PRINCIPAL COMPONENT 9 (0.20% variance)
# ----------------------------------------------------------------------------------------------------
#             Feature  Loading
#   context_2_pos_210   0.0728
# context_236_pos_327  -0.0695
#  context_210_pos_64   0.0682
#  context_106_pos_17   0.0652
#  context_574_pos_92  -0.0639
#  context_262_pos_63   0.0632
# context_132_pos_144   0.0604
# context_522_pos_320  -0.0602
# context_418_pos_112  -0.0588
# context_405_pos_368   0.0577
#
#
#
# PRINCIPAL COMPONENT 10 (0.19% variance)
# ----------------------------------------------------------------------------------------------------
#             Feature  Loading
#  context_626_pos_28  -0.0558
#   context_67_pos_11  -0.0504
#   context_2_pos_318   0.0425
# context_574_pos_410  -0.0414
# context_626_pos_500   0.0383
#  context_54_pos_185   0.0381
# context_379_pos_352   0.0376
# context_574_pos_381   0.0370
# context_587_pos_305  -0.0369
# context_509_pos_357   0.0361
# '====================================================================================================\nREGULAR PCA COMPONENTS (Top 10 Features per Component)\n====================================================================================================\n\nEXPLAINED VARIANCE SUMMARY:\nComponent Explained Variance (%) Cumulative Variance (%)\n      PC1                 77.11%                  77.11%\n      PC2                 11.30%                  88.41%\n      PC3                  2.80%                  91.21%\n      PC4                  1.69%                  92.90%\n      PC5                  0.72%                  93.62%\n      PC6                  0.63%                  94.25%\n      PC7                  0.42%                  94.67%\n      PC8                  0.31%                  94.98%\n      PC9                  0.20%                  95.18%\n     PC10                  0.19%                  95.37%\n\n====================================================================================================\n\n\nPRINCIPAL COMPONENT 1 (77.11% variance)\n----------------------------------------------------------------------------------------------------\n            Feature  Loading\n context_171_pos_97   0.0092\ncontext_314_pos_500   0.0091\ncontext_457_pos_300   0.0088\ncontext_535_pos_403   0.0088\ncontext_509_pos_344   0.0088\ncontext_275_pos_393   0.0088\n  context_67_pos_35   0.0087\ncontext_405_pos_370   0.0087\ncontext_509_pos_497   0.0087\n context_509_pos_95   0.0087\n\n\n\nPRINCIPAL COMPONENT 2 (11.30% variance)\n----------------------------------------------------------------------------------------------------\n            Feature  Loading\ncontext_574_pos_408  -0.0390\ncontext_197_pos_427  -0.0381\n context_574_pos_65  -0.0374\n context_574_pos_30  -0.0366\n context_28_pos_437  -0.0355\n context_561_pos_87  -0.0346\ncontext_509_pos_104  -0.0346\ncontext_509_pos_394  -0.0343\ncontext_457_pos_196  -0.0340\ncontext_314_pos_500  -0.0338\n\n\n\nPRINCIPAL COMPONENT 3 (2.80% variance)\n----------------------------------------------------------------------------------------------------\n            Feature  Loading\ncontext_132_pos_300   0.0198\ncontext_600_pos_123   0.0193\ncontext_379_pos_311   0.0189\ncontext_119_pos_145   0.0187\ncontext_197_pos_427   0.0187\ncontext_119_pos_395   0.0184\ncontext_496_pos_274   0.0182\n context_262_pos_64   0.0179\ncontext_522_pos_157   0.0176\n context_561_pos_87   0.0175\n\n\n\nPRINCIPAL COMPONENT 4 (1.69% variance)\n----------------------------------------------------------------------------------------------------\n            Feature  Loading\ncontext_132_pos_300  -0.0532\ncontext_119_pos_395  -0.0528\ncontext_132_pos_147  -0.0516\ncontext_262_pos_108  -0.0500\ncontext_132_pos_144  -0.0488\ncontext_223_pos_476  -0.0438\ncontext_600_pos_129  -0.0434\n context_54_pos_257  -0.0426\ncontext_639_pos_255  -0.0416\n  context_54_pos_52  -0.0411\n\n\n\nPRINCIPAL COMPONENT 5 (0.72% variance)\n----------------------------------------------------------------------------------------------------\n            Feature  Loading\n context_561_pos_41   0.0639\ncontext_132_pos_300   0.0565\ncontext_119_pos_395   0.0516\ncontext_418_pos_112   0.0492\ncontext_262_pos_108   0.0488\ncontext_444_pos_407   0.0486\n context_236_pos_44  -0.0474\ncontext_132_pos_297   0.0472\ncontext_288_pos_487   0.0471\ncontext_418_pos_511   0.0465\n\n\n\nPRINCIPAL COMPONENT 6 (0.63% variance)\n----------------------------------------------------------------------------------------------------\n            Feature  Loading\n context_67_pos_410   0.0226\ncontext_184_pos_170   0.0213\n context_457_pos_29   0.0211\n context_392_pos_51   0.0206\ncontext_236_pos_233   0.0206\n context_522_pos_38   0.0204\ncontext_314_pos_335   0.0200\ncontext_522_pos_339   0.0199\n context_392_pos_22   0.0198\n context_15_pos_501   0.0198\n\n\n\nPRINCIPAL COMPONENT 7 (0.42% variance)\n---------------------------------------------------- ...

# %%
from joint_pca import TrajectoryPlotter

plotter = TrajectoryPlotter(pca_handler)

fig = plotter.plot_pcs_over_time()
#fig.show()

raw_filename = plotter._get_filename()
filename = raw_filename + "_pcs_over_time"
fig.write_image(filename + ".png", scale=2)
fig.write_image(filename + ".pdf")
fig.write_html(filename + ".html")


for comp in range(1, 10+1):
    # comp with one leading zero in name
    filename = raw_filename + f"_loaded_features_comp{comp:02d}"
    fig = plotter.plot_top_loaded_features_for_component(component=comp, token_mapping=tokens_dict)
    fig.write_image(filename + ".png", scale=2)
    fig.write_html(filename + ".html")
    fig.write_image(filename + ".pdf")


# fig = plotter.plot_top_loaded_features_for_component(0, token_mapping=tokens_dict)
# fig.show()

# %%
from joint_pca import TrajectoryPCA

step_range = [1000, None]
n_components=0
n_sparse_components=10
scale=False
run_at_init=True
pca_handler = TrajectoryPCA(trajectory_data,
                            step_range = step_range,
                            n_components=n_components,
                            n_sparse_components=n_sparse_components,
                            scale=scale,
                            run_at_init=run_at_init,
                            sparse_pca_params={'alpha': 5},
                            dataset_name=dataset_name,
                            num_contexts=num_contexts,)
# Out:
# Found 25600 common columns across all 9 model sizes
# Concatenated matrix shape: (1287, 25600)
# Using full matrix for sparse PCA (no regular PCA performed): (1287, 25600)
# Sparse PCA: 10 components extracted
# Sparsity of components (fraction of zero values): [0.706640625, 0.75609375, 0.8569921875, 0.7283984375, 0.808046875, 0.7083203124999999, 0.820390625, 0.7345312500000001, 0.8752734375, 0.7445703125]

# %%
from joint_pca import TrajectoryPlotter
plotter = TrajectoryPlotter(pca_handler)

fig = plotter.plot_pcs_over_time()
fig.show()

raw_filename = plotter._get_filename()
filename = raw_filename + "_pcs_over_time"
fig.write_image(filename + ".png", scale=2)
fig.write_image(filename + ".pdf")
fig.write_html(filename + ".html")

# %%
for comp in range(1, 10+1):
    # comp with one leading zero in name
    filename = raw_filename + f"_loaded_features_comp{comp:02d}"
    fig = plotter.plot_top_loaded_features_for_component(component=comp, token_mapping=tokens_dict)
    fig.write_image(filename + ".png", scale=2)
    fig.write_image(filename + ".pdf")
    fig.write_html(filename + ".html")

# %%
from joint_pca import TrajectoryPCA

step_range = [2000, 30000]
n_components=0
n_sparse_components=10
scale=False
run_at_init=True
pca_handler = TrajectoryPCA(trajectory_data,
                            step_range = step_range,
                            n_components=n_components,
                            n_sparse_components=n_sparse_components,
                            scale=scale,
                            run_at_init=run_at_init,
                            sparse_pca_params={'alpha': 5},
                            dataset_name=dataset_name,
                            num_contexts=num_contexts,)
# Out:
# Found 25600 common columns across all 9 model sizes
# Concatenated matrix shape: (261, 25600)
# Using full matrix for sparse PCA (no regular PCA performed): (261, 25600)
# Sparse PCA: 10 components extracted
# Sparsity of components (fraction of zero values): [0.86140625, 0.8790625, 0.857578125, 0.8347265625, 0.8387890625, 0.9305859375, 0.8671484375, 0.9070703125, 0.8512109375, 0.9169921875]

# %%
import pandas as pd
columns_of_interest = [
    "context_2_pos_210",
    "context_2_pos_287",
    "context_54_pos_71",
    "context_54_pos_125",
    "context_54_pos_467",
    "context_119_pos_60",
    "context_119_pos_70",
    "context_119_pos_71",
    "context_119_pos_74",
    "context_119_pos_110",
    "context_119_pos_138",
    "context_119_pos_174",
    "context_119_pos_234",
    "context_119_pos_283",
    "context_119_pos_289",
    "context_119_pos_291",
    "context_132_pos_223",
    "context_132_pos_242",
    "context_262_pos_93",
    "context_288_pos_138",
    "context_392_pos_56",
    "context_444_pos_279",
    "context_483_pos_83",
    "context_509_pos_254",
    "context_561_pos_111",
    "context_587_pos_288",
    "context_600_pos_307",
    "context_600_pos_419",
    "context_600_pos_459",
    "context_600_pos_461"
]
loadings_on_columns = pca_handler.get_specific_column_loadings(columns_of_interest)

# print the full df horizontally
print(loadings_on_columns)



similarity = pca_handler.compute_cosine_with_spc(columns_of_interest)
print(similarity)
# Out:
#                 Feature   SPC1   SPC2    SPC3    SPC4    SPC5   SPC6    SPC7    SPC8    SPC9  \
# 0     context_2_pos_210 0.0000 0.0000  0.0003  0.0000 -0.0000 0.0622  0.0000  0.0882 -0.0000
# 1     context_2_pos_287 0.0000 0.0000  0.0000  0.0000 -0.0000 0.0000 -0.0025  0.0000 -0.0000
# 2     context_54_pos_71 0.0000 0.0017  0.0000  0.0000 -0.0000 0.0481  0.0000  0.0639 -0.0000
# 3    context_54_pos_125 0.0153 0.0000  0.0000 -0.0146 -0.0030 0.0000  0.0336  0.0295 -0.0000
# 4    context_54_pos_467 0.0000 0.0058  0.0000  0.0000 -0.0000 0.0780  0.0000  0.0000 -0.0000
# 5    context_119_pos_60 0.0000 0.0000  0.0000  0.0000 -0.0000 0.0238  0.0230  0.0595 -0.0034
# 6    context_119_pos_70 0.0000 0.0100  0.0000  0.0000 -0.0000 0.0374  0.0000 -0.0000 -0.0284
# 7    context_119_pos_71 0.0000 0.0000  0.0016  0.0039  0.0012 0.0622  0.0000  0.0000 -0.0000
# 8    context_119_pos_74 0.0000 0.0000  0.0000  0.0000 -0.0000 0.0676  0.0273  0.0000 -0.0000
# 9   context_119_pos_110 0.0000 0.0000  0.0000  0.0000 -0.0000 0.0000  0.0010  0.0794 -0.0164
# 10  context_119_pos_138 0.0000 0.0053  0.0000  0.0000 -0.0000 0.0475  0.0000  0.0000 -0.0000
# 11  context_119_pos_174 0.0000 0.0062  0.0000  0.0000 -0.0000 0.0491  0.0163  0.0258 -0.0000
# 12  context_119_pos_234 0.0111 0.0000 -0.0157  0.0000 -0.0000 0.0122  0.0000  0.0492 -0.0000
# 13  context_119_pos_283 0.0290 0.0015  0.0000 -0.0115 -0.0000 0.0042  0.0191  0.0048 -0.0000
# 14  context_119_pos_289 0.0000 0.0000 -0.0030 -0.0117 -0.0000 0.0179  0.0062  0.0023 -0.0000
# 15  context_119_pos_291 0.0000 0.0000 -0.0044  0.0000 -0.0000 0.0221  0.0060  0.0058 -0.0000
# 16  context_132_pos_223 0.0204 0.0041  0.0000  0.0000 -0.0019 0.0000  0.0000  0.0505 -0.0000
# 17  context_132_pos_242 0.0000 0.0332  0.0000 -0.0006 -0.0000 0.0205  0.0095  0.0101 -0.0000
# 18   context_262_pos_93 0.0000 0.0000  0.0000  0.0000 -0.0000 0.0611  0.0000  0.0188 -0.0000
# 19  context_288_pos_138 0.0000 0.0000  0.0000  0.0000 -0.0000 0.0000  0.0000  0.0000 -0.0000
# 20   context_392_pos_56 0.0118 0.0000  0.0000  0.0000 -0.0000 0.0912  0.0030  0.0000 -0.0018
# 21  context_444_pos_279 0.0138 0.0000  0.0000  0.0000 -0.0000 0.0000  0.0000  0.0082 -0.0000
# 22   context_483_pos_83 0.0000 0.0000  0.0000  0.0000 -0.0000 0.0469  0.0000  0.0314 -0.0000
# 23  context_509_pos_254 0.0453 0.0426  0.0000  0.0000 -0.0000 0.0000  0.0000  0.0128 -0.0000
# 24  context_561_pos_111 0.0000 0.0000  0.0000  0.0000 -0.0000 0.0408  0.0000  0.0428 -0.0000
# 25  context_587_pos_288 0.0026 0.0000  0.0000  0.0000 -0.0046 0.0010  0.0000  0.0408 -0.0000
# 26  context_600_pos_307 0.0000 0.0000  0.0000  0.0000 -0.0000 0.1023  0.0011  0.0000 -0.0000
# 27  context_600_pos_419 0.0000 0.0000  0.0000  0.0000 -0.0000 0.0817  0.0000  0.0124 -0.0000
# 28  context_600_pos_459 0.0000 0.0000  0.0000  0.0000 -0.0000 0.1064  0.0000  0.0650 -0.0000
# 29  context_600_pos_461 0.0000 0.0000  0.0000  0.0000 -0.0000 0.0592  0.0000  0.0254 -0.0000
#
#     SPC10
# 0  0.0000
# 1  0.0000
# 2  0.0106
# 3  0.0000
# 4  0.0000
# 5  0.0228
# 6  0.0000
# 7  0.0000
# 8  0.0003
# 9  0.0000
# 10 0.0000
# 11 0.0422
# 12 0.0000
# 13 0.0000
# 14 0.0000
# 15 0.0000
# 16 0.0000
# 17 0.0000
# 18 0.0149
# 19 0.0000
# 20 0.0080
# 21 0.0040
# 22 0.0123
# 23 0.0295
# 24 0.0000
# 25 0.0098
# 26 0.0027
# 27 0.0000
# 28 0.0240
# 29 0.0000
# 0.20872188199131136

# %%
for index in range(1,11):
    similarity = pca_handler.compute_cosine_with_spc(columns_of_interest, pc_idx=('sparse', index))
    # rounded to five decimals
    print(f'Similarity with SPC{index}: {similarity:.5f}')
# Out:
# Similarity with SPC1: 0.02728
# Similarity with SPC2: 0.02016
# Similarity with SPC3: -0.00389
# Similarity with SPC4: -0.00630
# Similarity with SPC5: -0.00151
# Similarity with SPC6: 0.20872
# Similarity with SPC7: 0.02620
# Similarity with SPC8: 0.13262
# Similarity with SPC9: -0.00914
# Similarity with SPC10: 0.03304

# %%
from joint_pca import TrajectoryPlotter
plotter = TrajectoryPlotter(pca_handler)

loadings_on_columns.to_csv(plotter._get_filename() + "_loadings_on_Dan_columns.csv")


fig = plotter.plot_pcs_over_time()
fig.show()

raw_filename = plotter._get_filename()
filename = raw_filename + "_pcs_over_time"
fig.write_image(filename + ".png", scale=2)
fig.write_image(filename + ".pdf")
fig.write_html(filename + ".html")

# %%
for comp in range(1, 10+1):
    # comp with one leading zero in name
    filename = raw_filename + f"_loaded_features_comp{comp:02d}"
    fig = plotter.plot_top_loaded_features_for_component(component=comp, token_mapping=tokens_dict)
    fig.write_image(filename + ".png", scale=2)
    fig.write_image(filename + ".pdf")
    fig.write_html(filename + ".html")

# fig = plotter.plot_top_loaded_features_for_component(6, token_mapping=tokens_dict)
# fig.show()

# %%
from joint_pca import TrajectoryPCA

step_range = [1000, None]
n_components=5
n_sparse_components=5
scale=False
run_at_init=True
pca_handler = TrajectoryPCA(trajectory_data,
                            step_range = step_range,
                            n_components=n_components,
                            n_sparse_components=n_sparse_components,
                            scale=scale,
                            run_at_init=run_at_init,
                            sparse_pca_params={'alpha': 5},
                            dataset_name=dataset_name,
                            num_contexts=num_contexts,)
# Out:
# Found 25600 common columns across all 9 model sizes
# Concatenated matrix shape: (1287, 25600)
# Regular PCA: Top 5 components explain 80.90% of variance
# Individual explained variance: [0.66704518 0.07896732 0.03161048 0.01791193 0.01341744]
# Residual matrix shape after regular PCA: (1287, 25600)
# Sparse PCA: 5 components extracted
# Sparsity of components (fraction of zero values): [0.7980078125, 0.8770703125, 0.85453125, 0.8985546875, 0.880625]

# %%
from joint_pca import TrajectoryPlotter
plotter = TrajectoryPlotter(pca_handler)

fig = plotter.plot_pcs_over_time()
fig.show()

raw_filename = plotter._get_filename()
filename = raw_filename + "_pcs_over_time"
fig.write_image(filename + ".png", scale=2)
fig.write_image(filename + ".pdf")
fig.write_html(filename + ".html")

# %%
for comp in range(1, 10+1):
    # comp with one leading zero in name
    filename = raw_filename + f"_loaded_features_comp{comp:02d}"
    fig = plotter.plot_top_loaded_features_for_component(component=comp, token_mapping=tokens_dict)
    fig.write_image(filename + ".png", scale=2)
    fig.write_image(filename + ".pdf")
    fig.write_html(filename + ".html")

# fig = plotter.plot_top_loaded_features_for_component(6, token_mapping=tokens_dict)
# fig.show()

# %%
from joint_pca import TrajectoryPCA

step_range = [2000, 30000]
n_components=0
n_sparse_components=10
scale=False
run_at_init=True
pca_handler = TrajectoryPCA(trajectory_data,
                            step_range = step_range,
                            n_components=n_components,
                            n_sparse_components=n_sparse_components,
                            scale=scale,
                            run_at_init=run_at_init,
                            sparse_pca_params={'alpha': 15},
                            dataset_name=dataset_name,
                            num_contexts=num_contexts,)
# Out:
# Found 25600 common columns across all 9 model sizes
# Concatenated matrix shape: (261, 25600)
# Using full matrix for sparse PCA (no regular PCA performed): (261, 25600)
# Sparse PCA: 10 components extracted
# Sparsity of components (fraction of zero values): [0.9453125, 0.946953125, 0.975859375, 0.9459765625, 0.9470703125, 0.999609375, 0.9644140625, 0.9652734375, 0.9488671875, 0.9616015625]

# %%
import pandas as pd
columns_of_interest = [
    "context_2_pos_210",
    "context_2_pos_287",
    "context_54_pos_71",
    "context_54_pos_125",
    "context_54_pos_467",
    "context_119_pos_60",
    "context_119_pos_70",
    "context_119_pos_71",
    "context_119_pos_74",
    "context_119_pos_110",
    "context_119_pos_138",
    "context_119_pos_174",
    "context_119_pos_234",
    "context_119_pos_283",
    "context_119_pos_289",
    "context_119_pos_291",
    "context_132_pos_223",
    "context_132_pos_242",
    "context_262_pos_93",
    "context_288_pos_138",
    "context_392_pos_56",
    "context_444_pos_279",
    "context_483_pos_83",
    "context_509_pos_254",
    "context_561_pos_111",
    "context_587_pos_288",
    "context_600_pos_307",
    "context_600_pos_419",
    "context_600_pos_459",
    "context_600_pos_461"
]
loadings_on_columns = pca_handler.get_specific_column_loadings(columns_of_interest)

# print the full df horizontally
print(loadings_on_columns)

for index in range(1,11):
    similarity = pca_handler.compute_cosine_with_spc(columns_of_interest, pc_idx=('sparse', index))
    # rounded to five decimals
    print(f'Similarity with SPC{index}: {similarity:.5f}')
# Out:
#                 Feature   SPC1   SPC2    SPC3   SPC4    SPC5   SPC6   SPC7   SPC8    SPC9  SPC10
# 0     context_2_pos_210 0.0000 0.0000  0.1359 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 1     context_2_pos_287 0.0000 0.0000 -0.0000 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 2     context_54_pos_71 0.0000 0.0000  0.1078 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 3    context_54_pos_125 0.0000 0.0664 -0.0000 0.0000 -0.0053 0.0000 0.0000 0.0000 -0.0000 0.0252
# 4    context_54_pos_467 0.0000 0.0000  0.0500 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 5    context_119_pos_60 0.0000 0.0153  0.0749 0.0000 -0.0000 0.0000 0.0000 0.0291 -0.0000 0.0000
# 6    context_119_pos_70 0.0000 0.0000 -0.0000 0.0000 -0.0000 0.0000 0.0058 0.0000 -0.0000 0.0428
# 7    context_119_pos_71 0.0000 0.0000  0.0236 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 8    context_119_pos_74 0.0000 0.0000  0.0760 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 9   context_119_pos_110 0.0000 0.0145  0.0333 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0342
# 10  context_119_pos_138 0.0000 0.0000  0.0195 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 11  context_119_pos_174 0.0000 0.0000  0.0875 0.0000 -0.0000 0.0000 0.0000 0.0315 -0.0000 0.0000
# 12  context_119_pos_234 0.0000 0.0331  0.0056 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0222
# 13  context_119_pos_283 0.0000 0.0275 -0.0000 0.0239 -0.0002 0.0000 0.0000 0.0000 -0.0000 0.0114
# 14  context_119_pos_289 0.0000 0.0163 -0.0000 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 15  context_119_pos_291 0.0000 0.0001  0.0072 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 16  context_132_pos_223 0.0000 0.0000 -0.0000 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0618
# 17  context_132_pos_242 0.0000 0.0000 -0.0000 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0500
# 18   context_262_pos_93 0.0000 0.0000  0.0697 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 19  context_288_pos_138 0.0000 0.0000 -0.0000 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 20   context_392_pos_56 0.0000 0.0000  0.0902 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 21  context_444_pos_279 0.0000 0.0019 -0.0000 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 22   context_483_pos_83 0.0000 0.0000  0.0680 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 23  context_509_pos_254 0.0000 0.0000 -0.0000 0.0000 -0.0000 0.0000 0.0651 0.0000 -0.0000 0.0670
# 24  context_561_pos_111 0.0000 0.0000  0.0612 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 25  context_587_pos_288 0.0000 0.0051  0.0258 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0022
# 26  context_600_pos_307 0.0000 0.0000  0.0767 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 27  context_600_pos_419 0.0000 0.0000  0.0661 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 28  context_600_pos_459 0.0000 0.0000  0.1822 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# 29  context_600_pos_461 0.0000 0.0000  0.0587 0.0000 -0.0000 0.0000 0.0000 0.0000 -0.0000 0.0000
# Similarity with SPC1: 0.00000
# Similarity with SPC2: 0.03291
# Similarity with SPC3: 0.24099
# Similarity with SPC4: 0.00437
# Similarity with SPC5: -0.00101
# Similarity with SPC6: 0.00000
# Similarity with SPC7: 0.01295
# Similarity with SPC8: 0.01106
# Similarity with SPC9: 0.00000
# Similarity with SPC10: 0.05783

# %%
from joint_pca import TrajectoryPlotter
plotter = TrajectoryPlotter(pca_handler)

fig = plotter.plot_pcs_over_time()
fig.show()

loadings_on_columns.to_csv(plotter._get_filename() + "_loadings_on_Dan_columns.csv")

raw_filename = plotter._get_filename()
filename = raw_filename + "_pcs_over_time"
fig.write_image(filename + ".png", scale=2)
fig.write_image(filename + ".pdf")
fig.write_html(filename + ".html")

for comp in range(1, 10+1):
    # comp with one leading zero in name
    filename = raw_filename + f"_loaded_features_comp{comp:02d}"
    fig = plotter.plot_top_loaded_features_for_component(component=comp, token_mapping=tokens_dict)
    fig.write_image(filename + ".png", scale=2)
    fig.write_image(filename + ".pdf")
    fig.write_html(filename + ".html")
